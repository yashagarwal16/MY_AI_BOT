# %%
from flask import Flask, request, jsonify
import os
import google.generativeai as genai
from flask_cors import CORS

app = Flask(__name__)
CORS(app)  # This will enable CORS for all routes

# Access the API key from the environment variable
api_key = os.getenv('GOOGLE_API_KEY', "AIzaSyDzRjvyVUQp6wIaQP0BtfFstuYNzM6vce4")

if not api_key:
    raise ValueError("No API key found in environment variable 'GOOGLE_API_KEY'")

genai.configure(api_key=api_key)

# Create the model
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 64,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-flash",
    generation_config=generation_config,
)

chat_session = model.start_chat(history=[])


@app.route('/goal', methods=['POST'])
def goal():
    data = request.get_json()
    query = data.get('query')

    if query:
        response = chat_session.send_message(query)
        response_text = response['choices'][0]['message']['content']
        return jsonify({'response': response_text})
    else:
        return jsonify({'error': 'No query provided'})

if __name__ == '__main__':
    app.run(port=80, host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:80
#  * Running on http://192.168.143.141:80
# Press CTRL+C to quit
# 127.0.0.1 - - [25/Aug/2024 15:28:54] "OPTIONS /chatbot HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Aug/2024 15:29:02] "OPTIONS /chatbot HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Aug/2024 15:29:35] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Aug/2024 15:29:35] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Aug/2024 15:30:42] "OPTIONS /goal HTTP/1.1" 200 -
# [2024-08-25 15:30:44,105] ERROR in app: Exception on /goal [POST]
# Traceback (most recent call last):
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\flask_cors\extension.py", line 178, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\AppData\Local\Temp\ipykernel_32820\3012034749.py", line 40, in goal
#     response = chat_session.send_message(query)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\generativeai\generative_models.py", line 578, in send_message
#     response = self.model.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\generativeai\generative_models.py", line 331, in generate_content
#     response = self._client.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py", line 827, in generate_content
#     response = rpc(
#                ^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\api_core\gapic_v1\method.py", line 131, in __call__
#     return wrapped_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py", line 293, in retry_wrapped_func
#     return retry_target(
#            ^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py", line 153, in retry_target
#     _retry_error_helper(
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\api_core\retry\retry_base.py", line 212, in _retry_error_helper
#     raise final_exc from source_exc
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\api_core\retry\retry_unary.py", line 144, in retry_target
#     result = target()
#              ^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\api_core\timeout.py", line 120, in func_with_timeout
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yash\anaconda3\Lib\site-packages\google\api_core\grpc_helpers.py", line 78, in error_remapped_callable
#     raise exceptions.from_grpc_error(exc) from exc
# google.api_core.exceptions.InvalidArgument: 400 API Key not found. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# ]
# 127.0.0.1 - - [25/Aug/2024 15:30:44] "POST /goal HTTP/1.1" 500 -
